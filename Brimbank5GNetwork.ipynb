# %% [markdown]
# <a href="https://colab.research.google.com/github/TheRealJasoandRazi/AI_For_Engineering_Group_Project/blob/main/Brimbank5GNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data_path = "clean_data.csv"

import pandas as pd

df = pd.read_csv(data_path)
df
# Out:
#                time         Convert_time       DATES      TIME      DAY  YEAR  \
# 0        1656877417  2022-07-04 05:43:37  2022-07-04  05:43:37   Monday  2022
# 1        1656877418  2022-07-04 05:43:38  2022-07-04  05:43:38   Monday  2022
# 2        1656877419  2022-07-04 05:43:39  2022-07-04  05:43:39   Monday  2022
# 3        1656877424  2022-07-04 05:43:44  2022-07-04  05:43:44   Monday  2022
# 4        1656877425  2022-07-04 05:43:45  2022-07-04  05:43:45   Monday  2022
# ...             ...                  ...         ...       ...      ...   ...
# 1063578  1657583480  2022-07-12 09:51:20  2022-07-12  09:51:20  Tuesday  2022
# 1063579  1657583481  2022-07-12 09:51:21  2022-07-12  09:51:21  Tuesday  2022
# 1063580  1657583482  2022-07-12 09:51:22  2022-07-12  09:51:22  Tuesday  2022
# 1063581  1657583483  2022-07-12 09:51:23  2022-07-12  09:51:23  Tuesday  2022
# 1063582  1657583485  2022-07-12 09:51:25  2022-07-12  09:51:25  Tuesday     2
#
# ...

# %%
features = df.columns.tolist()
print(features)
print(len(features))
# Out:
# ['time', 'Convert_time', 'DATES', 'TIME', 'DAY', 'YEAR', 'MONTH', 'DATE', 'HOUR', 'MIN', 'SEC', 'latitude', 'longitude', 'svr1', 'svr2', 'svr3', 'svr4', 'upload_transfer_size_mbytes', 'upload_bitrate_mbits/sec', 'download_transfer_size_rx_mbytes', 'download_bitrate_rx_mbits/sec', 'application_data', 'square_id']
# 23

# %%
missing_values_per_column = df.isnull().sum()
print("\nColumns with missing values:")
print(missing_values_per_column)
# Out:
# Columns with missing values:
# time                                0
# Convert_time                        0
# DATES                               0
# TIME                                0
# DAY                                 0
# YEAR                                0
# MONTH                               0
# DATE                                0
# HOUR                                0
# MIN                                 0
# SEC                                 0
# latitude                            0
# longitude                           0
# svr1                                0
# svr2                                0
# svr3                                0
# svr4                                0
# upload_transfer_size_mbytes         0
# upload_bitrate_mbits/sec            0
# download_transfer_size_rx_mbytes    0
# download_bitrate_rx_mbits/sec       0
# application_data                    0
# square_id                           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

for feature in features:
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    plt.hist(df[feature], bins=20, edgecolor='black')  # Adjust number of bins
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.grid(True)  # Add a grid for better readability
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-3e9d838df13c> in <cell line: 0>()
#       8     plt.ylabel('Frequency')
#       9     plt.grid(True)  # Add a grid for better readability
# ---> 10     plt.show()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     612     """
#     613     _warn_if_gui_out_of_main_thread()
# --> 614     return _get_backend_mod().show(*args, **kwargs)
#     615
#     616
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
